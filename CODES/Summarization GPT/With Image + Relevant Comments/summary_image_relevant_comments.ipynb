# %%
import openai
from openai import OpenAI
import os
import pandas as pd
import tiktoken
import csv

GPT_API_KEY = 'YOUR_API_KEY_HERE'
os.environ['OPENAI_API_KEY'] = GPT_API_KEY
openai.api_key = GPT_API_KEY
client = OpenAI()

tokenizer = tiktoken.get_encoding('cl100k_base')

# %%
language = "Hindi"

# Read both CSV files
relevant_comments_data = pd.read_csv(f"{language}_Relevant_Comments.csv")
reference_summary_data = pd.read_csv(f"{language}_Reference_Summary.csv")

def generate_summary(text, comments, img_url):
    # Ensure the text is a string
    if not isinstance(text, str):
        return None
    
    # Prepare the messages for the API call
    messages = [
        {
            "role": "system",
            "content": "You are an expert news editor. Your primary task is to create summaries that accurately reflect the main content of news articles and images. User comments should be considered as supplementary information only."
        },
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": f"""Craft a precise and engaging news summary in {language} that primarily summarizes the main point of the article or image. Use insights from user comments only as secondary, supplementary information. Follow these guidelines:

1. Focus predominantly (about 80-90%) on the key information and main message from the article or image.
2. If relevant, subtly incorporate a minor element (about 10-20%) from the user comments to reflect public sentiment or add context.
3. Use active voice and clear, impactful language.
4. Ensure the summary is factual and directly related to the article's main content or the key elements of the image.
5. Avoid overemphasizing or sensationalizing elements from user comments.
6. If an image is provided, balance the summary to reflect both textual and visual information when applicable.

Article content: {text}

Brief summary of relevant user comment insights (use sparingly):
{comments}

summary:"""
                }
            ],
        }
    ]
    
    # Try to add the image URL if it's provided and valid
    if img_url:
        try:
            messages[1]["content"].append({
                "type": "image_url",
                "image_url": {
                    "url": img_url,
                },
            })
        except Exception as e:
            print(f"Error processing image URL: {e}. Continuing without image.")
    
    try:
        # Call the model with the prepared messages
        completion = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=messages,
        )
        
        summary = completion.choices[0].message.content
        print("summary_generated")
        return summary
    except Exception as e:
        print(f"Error generating summary: {e}")
        
        return None

# Now update your DataFrame

# %%
# Generate summaries for the relevant comments data
generated_summaries = []
for index, row in relevant_comments_data.iterrows():
    summary = generate_summary(row['Content'], row.get('cleaned_comments', ''), row.get('Image URL', ''))
    generated_summaries.append(summary)
    print(f"Processed article {index + 1} of {len(relevant_comments_data)}")

# Add the generated summaries to the reference summary data
reference_summary_data['Generated Summary'] = generated_summaries

# Save the updated reference summary data
reference_summary_data.to_csv(f'{language}_Summary_With_Image_Relevant_Comments.csv', index=False, encoding='utf-8')

print(f"Summaries generated and added to '{language}_Summary_With_Image_Relevant_Comments.csv'")
# Out:
# summary_generated
# Processed article 1 of 543
# summary_generated
# Processed article 2 of 543
# summary_generated
# Processed article 3 of 543
# summary_generated
# Processed article 4 of 543
# summary_generated
# Processed article 5 of 543
# summary_generated
# Processed article 6 of 543
# summary_generated
# Processed article 7 of 543
# summary_generated
# Processed article 8 of 543
# summary_generated
# Processed article 9 of 543
# summary_generated
# Processed article 10 of 543
# summary_generated
# Processed article 11 of 543
# summary_generated
# Processed article 12 of 543
# summary_generated
# Processed article 13 of 543
# summary_generated
# Processed article 14 of 543
# summary_generated
# Processed article 15 of 543
# summary_generated
# Processed article 16 of 543
# summary_generated
# Processed article 17 of 543
# summary_generated
# Processed article 18 of 543
# summary_generated
# Processed article 19 of 543
# summary_generated
# Processed article 20 of 543
# summary_generated
# Processed article 21 of 543
# summary_generated
# Processed article 22 of 543
# summary_generated
# Processed article 23 of 543
# summary_generated
# Processed article 24 of 543
# summary_generated
# Processed article 25 of 543
# summary_generated
# Processed article 26 of 543
# summary_generated
# Processed article 27 of 543
# summary_generated
# Processed article 28 of 543
# summary_generated
# Processed article 29 of 543
# summary_generated
# Processed article 30 of 543
# summary_generated
# Processed article 31 of 543
# summary_generated
# Processed article 32 of 543
# summary_generated
# Processed article 33 of 543
# summary_generated
# Processed article 34 of 543
# summary_generated
# Processed article 35 of 543
# summary_generated
# Processed article 36 of 543
# summary_generated
# Processed article 37 of 543
# summary_generated
# Processed article 38 of 543
# summary_generated
# Processed article 39 of 543
# summary_generated
# Processed article 40 of 543
# summary_generated
# Processed article 41 of 543
# summary_generated
# Processed article 42 of 543
# summary_generated
# Processed article 43 of 543
# summary_generated
# Processed article 44 of 543
# summary_generated
# Processed article 45 of 543
# summary_generated
# Processed article 46 of 543
# summary_generated
# Processed article 47 of 543
# summary_generated
# Processed article 48 of 543
# summary_generated
# Processed article 49 of 543
# summary_generated
# Processed article 50 of 543
# summary_generated
# Processed article 51 of 543
# summary_generated
# Processed article 52 of 543
# summary_generated
# Processed article 53 of 543
# summary_generated
# Processed article 54 of 543
# summary_generated
# Processed article 55 of 543
# summary_generated
# Processed article 56 of 543
# summary_generated
# Processed article 57 of 543
# summary_generated
# Processed article 58 of 543
# summary_generated
# Processed article 59 of 543
# summary_generated
# Processed article 60 of 543
# summary_generated
# Processed article 61 of 543
# summary_generated
# Processed article 62 of 543
# summary_generated
# Processed article 63 of 543
# summary_generated
# Processed article 64 of 543
# summary_generated
# Processed article 65 of 543
# summary_generated
# Processed article 66 of 543
# summary_generated
# Processed article 67 of 543
# summary_generated
# Processed article 68 of 543
# summary_generated
# Processed article 69 of 543
# summary_generated
# Processed article 70 of 543
# summary_generated
# Processed article 71 of 543
# summary_generated
# Processed article 72 of 543
# summary_generated
# Processed article 73 of 543
# summary_generated
# Processed article 74 of 543
# summary_generated
# Processed article 75 of 543
# summary_generated
# Processed article 76 of 543
# summary_generated
# Processed article 77 of 543
# summary_generated
# Processed article 78 of 543
# summary_generated
# Processed article 79 of 543
# summary_generated
# Processed article 80 of 543
# summary_generated
# Processed article 81 of 543
# summary_generated
# Processed article 82 of 543
# summary_generated
# Processed article 83 of 543
# summary_generated
# Processed article 84 of 543
# summary_generated
# Processed article 85 of 543
# summary_generated
# Processed article 86 of 543
# summary_generated
# Processed article 87 of 543
# summary_generated
# Processed article 88 of 543
# summary_generated
# Processed article 89 of 543
# summary_generated
# Processed article 90 of 543
# summary_generated
# Processed article 91 of 543
# summary_generated
# Processed article 92 of 543
# summary_generated
# Processed article 93 of 543
# summary_generated
# Processed article 94 of 543
# summary_generated
# Processed article 95 of 543
# summary_generated
# Processed article 96 of 543
# summary_generated
# Processed article 97 of 543
# summary_generated
# Processed article 98 of 543
# summary_generated
# Processed article 99 of 543
# summary_generated
# Processed article 100 of 543
# summary_generated
# Processed article 101 of 543
# summary_generated
# Processed article 102 of 543
# summary_generated
# Processed article 103 of 543
# summary_generated
# Processed article 104 of 543
# summary_generated
# Processed article 105 of 543
# summary_generated
# Processed article 106 of 543
# summary_generated
# Processed article 107 of 543
# summary_generated
# Processed article 108 of 543
# summary_generated
# Processed article 109 of 543
# summary_generated
# Processed article 110 of 543
# summary_generated
# Processed article 111 of 543
# summary_generated
# Processed article 112 of 543
# summary_generated
# Processed article 113 of 543
# summary_generated
# Processed article 114 of 543
# summary_generated
# Processed article 115 of 543
# summary_generated
# Processed article 116 of 543
# summary_generated
# Processed article 117 of 543
# summary_generated
# Processed article 118 of 543
# summary_generated
# Processed article 119 of 543
# summary_generated
# Processed article 120 of 543
# summary_generated
# Processed article 121 of 543
# summary_generated
# Processed article 122 of 543
# summary_generated
# Processed article 123 of 543
# summary_generated
# Processed article 124 of 543
# summary_generated
# Processed article 125 of 543
# summary_generated
# Processed article 126 of 543
# summary_generated
# Processed article 127 of 543
# summary_generated
# Processed article 128 of 543
# summary_generated
# Processed article 129 of 543
# summary_generated
# Processed article 130 of 543
# summary_generated
# Processed article 131 of 543
# summary_generated
# Processed article 132 of 543
# summary_generated
# Processed article 133 of 543
# summary_generated
# Processed article 134 of 543
# summary_generated
# Processed article 135 of 543
# summary_generated
# Processed article 136 of 543
# summary_generated
# Processed article 137 of 543
# summary_generated
# Processed article 138 of 543
# summary_generated
# Processed article 139 of 543
# summary_generated
# Processed article 140 of 543
# summary_generated
# Processed article 141 of 543
# summary_generated
# Processed article 142 of 543
# summary_generated
# Processed article 143 of 543
# summary_generated
# Processed article 144 of 543
# summary_generated
# Processed article 145 of 543
# summary_generated
# Processed article 146 of 543
# summary_generated
# Processed article 147 of 543
# summary_generated
# Processed article 148 of 543
# summary_generated
# Processed article 149 of 543
# summary_generated
# Processed article 150 of 543
# summary_generated
# Processed article 151 of 543
# summary_generated
# Processed article 152 of 543
# summary_generated
# Processed article 153 of 543
# summary_generated
# Processed article 154 of 543
# summary_generated
# Processed article 155 of 543
# summary_generated
# Processed article 156 of 543
# summary_generated
# Processed article 157 of 543
# summary_generated
# Processed article 158 of 543
# summary_generated
# Processed article 159 of 543
# summary_generated
# Processed article 160 of 543
# summary_generated
# Processed article 161 of 543
# summary_generated
# Processed article 162 of 543
# summary_generated
# Processed article 163 of 543
# summary_generated
# Processed article 164 of 543
# summary_generated
# Processed article 165 of 543
# summary_generated
# Processed article 166 of 543
# summary_generated
# Processed article 167 of 543
# summary_generated
# Processed article 168 of 543
# summary_generated
# Processed article 169 of 543
# summary_generated
# Processed article 170 of 543
# summary_generated
# Processed article 171 of 543
# summary_generated
# Processed article 172 of 543
# summary_generated
# Processed article 173 of 543
# summary_generated
# Processed article 174 of 543
# summary_generated
# Processed article 175 of 543
# summary_generated
# Processed article 176 of 543
# summary_generated
# Processed article 177 of 543
# summary_generated
# Processed article 178 of 543
# summary_generated
# Processed article 179 of 543
# summary_generated
# Processed article 180 of 543
# summary_generated
# Processed article 181 of 543
# summary_generated
# Processed article 182 of 543
# summary_generated
# Processed article 183 of 543
# summary_generated
# Processed article 184 of 543
# summary_generated
# Processed article 185 of 543
# summary_generated
# Processed article 186 of 543
# summary_generated
# Processed article 187 of 543
# summary_generated
# Processed article 188 of 543
# summary_generated
# Processed article 189 of 543
# summary_generated
# Processed article 190 of 543
# summary_generated
# Processed article 191 of 543
# summary_generated
# Processed article 192 of 543
# summary_generated
# Processed article 193 of 543
# summary_generated
# Processed article 194 of 543
# summary_generated
# Processed article 195 of 543
# summary_generated
# Processed article 196 of 543
# summary_generated
# Processed article 197 of 543
# summary_generated
# Processed article 198 of 543
# summary_generated
# Processed article 199 of 543
# summary_generated
# Processed article 200 of 543
# summary_generated
# Processed article 201 of 543
# summary_generated
# Processed article 202 of 543
# summary_generated
# Processed article 203 of 543
# summary_generated
# Processed article 204 of 543
# summary_generated
# Processed article 205 of 543
# summary_generated
# Processed article 206 of 543
# summary_generated
# Processed article 207 of 543
# summary_generated
# Processed article 208 of 543
# summary_generated
# Processed article 209 of 543
# summary_generated
# Processed article 210 of 543
# summary_generated
# Processed article 211 of 543
# summary_generated
# Processed article 212 of 543
# summary_generated
# Processed article 213 of 543
# summary_generated
# Processed article 214 of 543
# summary_generated
# Processed article 215 of 543
# summary_generated
# Processed article 216 of 543
# summary_generated
# Processed article 217 of 543
# summary_generated
# Processed article 218 of 543
# summary_generated
# Processed article 219 of 543
# summary_generated
# Processed article 220 of 543
# summary_generated
# Processed article 221 of 543
# summary_generated
# Processed article 222 of 543
# summary_generated
# Processed article 223 of 543
# summary_generated
# Processed article 224 of 543
# summary_generated
# Processed article 225 of 543
# summary_generated
# Processed article 226 of 543
# summary_generated
# Processed article 227 of 543
# summary_generated
# Processed article 228 of 543
# summary_generated
# Processed article 229 of 543
# summary_generated
# Processed article 230 of 543
# summary_generated
# Processed article 231 of 543
# summary_generated
# Processed article 232 of 543
# summary_generated
# Processed article 233 of 543
# summary_generated
# Processed article 234 of 543
# summary_generated
# Processed article 235 of 543
# summary_generated
# Processed article 236 of 543
# summary_generated
# Processed article 237 of 543
# summary_generated
# Processed article 238 of 543
# summary_generated
# Processed article 239 of 543
# summary_generated
# Processed article 240 of 543
# summary_generated
# Processed article 241 of 543
# summary_generated
# Processed article 242 of 543
# summary_generated
# Processed article 243 of 543
# summary_generated
# Processed article 244 of 543
# summary_generated
# Processed article 245 of 543
# summary_generated
# Processed article 246 of 543
# summary_generated
# Processed article 247 of 543
# summary_generated
# Processed article 248 of 543
# summary_generated
# Processed article 249 of 543
# summary_generated
# Processed article 250 of 543
# summary_generated
# Processed article 251 of 543
# summary_generated
# Processed article 252 of 543
# summary_generated
# Processed article 253 of 543
# summary_generated
# Processed article 254 of 543
# summary_generated
# Processed article 255 of 543
# summary_generated
# Processed article 256 of 543
# summary_generated
# Processed article 257 of 543
# summary_generated
# Processed article 258 of 543
# summary_generated
# Processed article 259 of 543
# summary_generated
# Processed article 260 of 543
# summary_generated
# Processed article 261 of 543
# summary_generated
# Processed article 262 of 543
# summary_generated
# Processed article 263 of 543
# summary_generated
# Processed article 264 of 543
# summary_generated
# Processed article 265 of 543
# summary_generated
# Processed article 266 of 543
# summary_generated
# Processed article 267 of 543
# summary_generated
# Processed article 268 of 543
# summary_generated
# Processed article 269 of 543
# summary_generated
# Processed article 270 of 543
# summary_generated
# Processed article 271 of 543
# summary_generated
# Processed article 272 of 543
# summary_generated
# Processed article 273 of 543
# summary_generated
# Processed article 274 of 543
# summary_generated
# Processed article 275 of 543
# summary_generated
# Processed article 276 of 543
# summary_generated
# Processed article 277 of 543
# summary_generated
# Processed article 278 of 543
# summary_generated
# Processed article 279 of 543
# summary_generated
# Processed article 280 of 543
# summary_generated
# Processed article 281 of 543
# summary_generated
# Processed article 282 of 543
# summary_generated
# Processed article 283 of 543
# summary_generated
# Processed article 284 of 543
# summary_generated
# Processed article 285 of 543
# summary_generated
# Processed article 286 of 543
# summary_generated
# Processed article 287 of 543
# summary_generated
# Processed article 288 of 543
# summary_generated
# Processed article 289 of 543
# summary_generated
# Processed article 290 of 543
# summary_generated
# Processed article 291 of 543
# summary_generated
# Processed article 292 of 543
# summary_generated
# Processed article 293 of 543
# summary_generated
# Processed article 294 of 543
# summary_generated
# Processed article 295 of 543
# summary_generated
# Processed article 296 of 543
# summary_generated
# Processed article 297 of 543
# summary_generated
# Processed article 298 of 543
# summary_generated
# Processed article 299 of 543
# summary_generated
# Processed article 300 of 543
# summary_generated
# Processed article 301 of 543
# summary_generated
# Processed article 302 of 543
# summary_generated
# Processed article 303 of 543
# summary_generated
# Processed article 304 of 543
# summary_generated
# Processed article 305 of 543
# summary_generated
# Processed article 306 of 543
# summary_generated
# Processed article 307 of 543
# summary_generated
# Processed article 308 of 543
# summary_generated
# Processed article 309 of 543
# summary_generated
# Processed article 310 of 543
# summary_generated
# Processed article 311 of 543
# summary_generated
# Processed article 312 of 543
# summary_generated
# Processed article 313 of 543
# summary_generated
# Processed article 314 of 543
# summary_generated
# Processed article 315 of 543
# summary_generated
# Processed article 316 of 543
# summary_generated
# Processed article 317 of 543
# summary_generated
# Processed article 318 of 543
# summary_generated
# Processed article 319 of 543
# summary_generated
# Processed article 320 of 543
# summary_generated
# Processed article 321 of 543
# summary_generated
# Processed article 322 of 543
# summary_generated
# Processed article 323 of 543
# summary_generated
# Processed article 324 of 543
# summary_generated
# Processed article 325 of 543
# summary_generated
# Processed article 326 of 543
# summary_generated
# Processed article 327 of 543
# summary_generated
# Processed article 328 of 543
# summary_generated
# Processed article 329 of 543
# summary_generated
# Processed article 330 of 543
# summary_generated
# Processed article 331 of 543
# summary_generated
# Processed article 332 of 543
# summary_generated
# Processed article 333 of 543
# summary_generated
# Processed article 334 of 543
# summary_generated
# Processed article 335 of 543
# summary_generated
# Processed article 336 of 543
# summary_generated
# Processed article 337 of 543
# summary_generated
# Processed article 338 of 543
# summary_generated
# Processed article 339 of 543
# summary_generated
# Processed article 340 of 543
# summary_generated
# Processed article 341 of 543
# summary_generated
# Processed article 342 of 543
# summary_generated
# Processed article 343 of 543
# summary_generated
# Processed article 344 of 543
# summary_generated
# Processed article 345 of 543
# summary_generated
# Processed article 346 of 543
# summary_generated
# Processed article 347 of 543
# summary_generated
# Processed article 348 of 543
# summary_generated
# Processed article 349 of 543
# summary_generated
# Processed article 350 of 543
# summary_generated
# Processed article 351 of 543
# summary_generated
# Processed article 352 of 543
# summary_generated
# Processed article 353 of 543
# summary_generated
# Processed article 354 of 543
# summary_generated
# Processed article 355 of 543
# summary_generated
# Processed article 356 of 543
# summary_generated
# Processed article 357 of 543
# summary_generated
# Processed article 358 of 543
# summary_generated
# Processed article 359 of 543
# summary_generated
# Processed article 360 of 543
# summary_generated
# Processed article 361 of 543
# summary_generated
# Processed article 362 of 543
# summary_generated
# Processed article 363 of 543
# summary_generated
# Processed article 364 of 543
# summary_generated
# Processed article 365 of 543
# summary_generated
# Processed article 366 of 543
# summary_generated
# Processed article 367 of 543
# summary_generated
# Processed article 368 of 543
# summary_generated
# Processed article 369 of 543
# summary_generated
# Processed article 370 of 543
# summary_generated
# Processed article 371 of 543
# summary_generated
# Processed article 372 of 543
# summary_generated
# Processed article 373 of 543
# summary_generated
# Processed article 374 of 543
# summary_generated
# Processed article 375 of 543
# summary_generated
# Processed article 376 of 543
# summary_generated
# Processed article 377 of 543
# summary_generated
# Processed article 378 of 543
# summary_generated
# Processed article 379 of 543
# summary_generated
# Processed article 380 of 543
# summary_generated
# Processed article 381 of 543
# summary_generated
# Processed article 382 of 543
# summary_generated
# Processed article 383 of 543
# summary_generated
# Processed article 384 of 543
# summary_generated
# Processed article 385 of 543
# summary_generated
# Processed article 386 of 543
# summary_generated
# Processed article 387 of 543
# summary_generated
# Processed article 388 of 543
# summary_generated
# Processed article 389 of 543
# summary_generated
# Processed article 390 of 543
# summary_generated
# Processed article 391 of 543
# summary_generated
# Processed article 392 of 543
# summary_generated
# Processed article 393 of 543
# summary_generated
# Processed article 394 of 543
# summary_generated
# Processed article 395 of 543
# summary_generated
# Processed article 396 of 543
# summary_generated
# Processed article 397 of 543
# summary_generated
# Processed article 398 of 543
# summary_generated
# Processed article 399 of 543
# summary_generated
# Processed article 400 of 543
# summary_generated
# Processed article 401 of 543
# summary_generated
# Processed article 402 of 543
# summary_generated
# Processed article 403 of 543
# summary_generated
# Processed article 404 of 543
# summary_generated
# Processed article 405 of 543
# summary_generated
# Processed article 406 of 543
# summary_generated
# Processed article 407 of 543
# summary_generated
# Processed article 408 of 543
# summary_generated
# Processed article 409 of 543
# summary_generated
# Processed article 410 of 543
# summary_generated
# Processed article 411 of 543
# summary_generated
# Processed article 412 of 543
# summary_generated
# Processed article 413 of 543
# summary_generated
# Processed article 414 of 543
# summary_generated
# Processed article 415 of 543
# summary_generated
# Processed article 416 of 543
# summary_generated
# Processed article 417 of 543
# summary_generated
# Processed article 418 of 543
# summary_generated
# Processed article 419 of 543
# summary_generated
# Processed article 420 of 543
# summary_generated
# Processed article 421 of 543
# summary_generated
# Processed article 422 of 543
# summary_generated
# Processed article 423 of 543
# summary_generated
# Processed article 424 of 543
# summary_generated
# Processed article 425 of 543
# summary_generated
# Processed article 426 of 543
# summary_generated
# Processed article 427 of 543
# summary_generated
# Processed article 428 of 543
# summary_generated
# Processed article 429 of 543
# summary_generated
# Processed article 430 of 543
# summary_generated
# Processed article 431 of 543
# summary_generated
# Processed article 432 of 543
# summary_generated
# Processed article 433 of 543
# summary_generated
# Processed article 434 of 543
# summary_generated
# Processed article 435 of 543
# summary_generated
# Processed article 436 of 543
# summary_generated
# Processed article 437 of 543
# summary_generated
# Processed article 438 of 543
# summary_generated
# Processed article 439 of 543
# summary_generated
# Processed article 440 of 543
# summary_generated
# Processed article 441 of 543
# summary_generated
# Processed article 442 of 543
# summary_generated
# Processed article 443 of 543
# summary_generated
# Processed article 444 of 543
# summary_generated
# Processed article 445 of 543
# summary_generated
# Processed article 446 of 543
# summary_generated
# Processed article 447 of 543
# summary_generated
# Processed article 448 of 543
# summary_generated
# Processed article 449 of 543
# summary_generated
# Processed article 450 of 543
# summary_generated
# Processed article 451 of 543
# summary_generated
# Processed article 452 of 543
# summary_generated
# Processed article 453 of 543
# summary_generated
# Processed article 454 of 543
# summary_generated
# Processed article 455 of 543
# summary_generated
# Processed article 456 of 543
# summary_generated
# Processed article 457 of 543
# summary_generated
# Processed article 458 of 543
# summary_generated
# Processed article 459 of 543
# summary_generated
# Processed article 460 of 543
# summary_generated
# Processed article 461 of 543
# summary_generated
# Processed article 462 of 543
# summary_generated
# Processed article 463 of 543
# summary_generated
# Processed article 464 of 543
# summary_generated
# Processed article 465 of 543
# summary_generated
# Processed article 466 of 543
# summary_generated
# Processed article 467 of 543
# summary_generated
# Processed article 468 of 543
# summary_generated
# Processed article 469 of 543
# summary_generated
# Processed article 470 of 543
# summary_generated
# Processed article 471 of 543
# summary_generated
# Processed article 472 of 543
# summary_generated
# Processed article 473 of 543
# summary_generated
# Processed article 474 of 543
# summary_generated
# Processed article 475 of 543
# summary_generated
# Processed article 476 of 543
# summary_generated
# Processed article 477 of 543
# summary_generated
# Processed article 478 of 543
# summary_generated
# Processed article 479 of 543
# summary_generated
# Processed article 480 of 543
# summary_generated
# Processed article 481 of 543
# summary_generated
# Processed article 482 of 543
# summary_generated
# Processed article 483 of 543
# summary_generated
# Processed article 484 of 543
# summary_generated
# Processed article 485 of 543
# summary_generated
# Processed article 486 of 543
# summary_generated
# Processed article 487 of 543
# summary_generated
# Processed article 488 of 543
# summary_generated
# Processed article 489 of 543
# summary_generated
# Processed article 490 of 543
# summary_generated
# Processed article 491 of 543
# summary_generated
# Processed article 492 of 543
# summary_generated
# Processed article 493 of 543
# summary_generated
# Processed article 494 of 543
# summary_generated
# Processed article 495 of 543
# summary_generated
# Processed article 496 of 543
# summary_generated
# Processed article 497 of 543
# summary_generated
# Processed article 498 of 543
# summary_generated
# Processed article 499 of 543
# summary_generated
# Processed article 500 of 543
# summary_generated
# Processed article 501 of 543
# summary_generated
# Processed article 502 of 543
# summary_generated
# Processed article 503 of 543
# summary_generated
# Processed article 504 of 543
# summary_generated
# Processed article 505 of 543
# summary_generated
# Processed article 506 of 543
# summary_generated
# Processed article 507 of 543
# summary_generated
# Processed article 508 of 543
# summary_generated
# Processed article 509 of 543
# summary_generated
# Processed article 510 of 543
# summary_generated
# Processed article 511 of 543
# summary_generated
# Processed article 512 of 543
# summary_generated
# Processed article 513 of 543
# summary_generated
# Processed article 514 of 543
# summary_generated
# Processed article 515 of 543
# summary_generated
# Processed article 516 of 543
# summary_generated
# Processed article 517 of 543
# summary_generated
# Processed article 518 of 543
# summary_generated
# Processed article 519 of 543
# summary_generated
# Processed article 520 of 543
# summary_generated
# Processed article 521 of 543
# summary_generated
# Processed article 522 of 543
# summary_generated
# Processed article 523 of 543
# summary_generated
# Processed article 524 of 543
# summary_generated
# Processed article 525 of 543
# summary_generated
# Processed article 526 of 543
# summary_generated
# Processed article 527 of 543
# summary_generated
# Processed article 528 of 543
# summary_generated
# Processed article 529 of 543
# summary_generated
# Processed article 530 of 543
# summary_generated
# Processed article 531 of 543
# summary_generated
# Processed article 532 of 543
# summary_generated
# Processed article 533 of 543
# summary_generated
# Processed article 534 of 543
# summary_generated
# Processed article 535 of 543
# summary_generated
# Processed article 536 of 543
# summary_generated
# Processed article 537 of 543
# summary_generated
# Processed article 538 of 543
# summary_generated
# Processed article 539 of 543
# summary_generated
# Processed article 540 of 543
# summary_generated
# Processed article 541 of 543
# summary_generated
# Processed article 542 of 543
# summary_generated
# Processed article 543 of 543
# Summaries generated and added to 'Hindi_Summary_With_Relevant_Comments.csv'
